# %% [markdown]
# 정규 표현식을 사용해 길이가 1~2자인 짧은 단어를 제거하는 정제 예제입니다. 불필요한 짧은 토큰을 줄여 텍스트를 더 깔끔하게 만듭니다.

# %%
import re
text = "I was wondering if anyone out there could enlighten me on this car."

# 길이가 1~2인 단어들을 정규 표현식을 이용하여 삭제
shortword = re.compile(r'\W*\b\w{1,2}\b\W*')
print(shortword.sub('', text))
# Out:
# was wonderinganyone out there could enlightenthis car.
