# %%
import re

# %%
r = re.compile("a.c")
r.search("kkk")

# %%
r.search("abc")
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %%
import re

text = "Hello!!! 자연어처리?! 2026년 공부중"

# 1. 특수문자 제거
re.sub(r"[^가-힣a-zA-Z0-9\s]", "", text)

# 2. 숫자 제거
re.sub(r"\d+", "", text)

# 3. 여러 공백 하나로 줄이기
cleaned = re.sub(r"\s+", " ", text)
cleaned.strip()

# 4. 한글과 영어만 남기기
re.sub(r"[^가-힣a-zA-Z\s]", "", text)
